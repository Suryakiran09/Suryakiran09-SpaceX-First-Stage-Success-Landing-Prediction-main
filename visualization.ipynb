# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
dataset = pd.read_csv('dataset_part_2.csv')
dataset
# Out:
#     FlightNumber        Date BoosterVersion   PayloadMass Orbit    LaunchSite  \
# 0              1  2010-06-04       Falcon 9   6104.959412   LEO  CCAFS SLC 40
# 1              2  2012-05-22       Falcon 9    525.000000   LEO  CCAFS SLC 40
# 2              3  2013-03-01       Falcon 9    677.000000   ISS  CCAFS SLC 40
# 3              4  2013-09-29       Falcon 9    500.000000    PO   VAFB SLC 4E
# 4              5  2013-12-03       Falcon 9   3170.000000   GTO  CCAFS SLC 40
# ..           ...         ...            ...           ...   ...           ...
# 85            86  2020-09-03       Falcon 9  15400.000000  VLEO    KSC LC 39A
# 86            87  2020-10-06       Falcon 9  15400.000000  VLEO    KSC LC 39A
# 87            88  2020-10-18       Falcon 9  15400.000000  VLEO    KSC LC 39A
# 88            89  2020-10-24       Falcon 9  15400.000000  VLEO  CCAFS SLC 40
# 89            90  2020-11-05       Falcon 9   3681.000000   MEO  CCAFS SLC 40
#
# ...

# %% [markdown]
# ###Visualizing the Data

# %%
plt.figure(figsize = (20,5))
plt.subplot(1,2,1)
sns.histplot(dataset.Class,color = 'r')
# Out:
# <Axes: xlabel='Class', ylabel='Count'>

# %%
plt.subplot(1,2,1)
sns.histplot(dataset.PayloadMass,color = 'r')
# Out:
# <Axes: xlabel='PayloadMass', ylabel='Count'>

# %%
plt.subplot(1,2,1)
sns.histplot(dataset.GridFins,color = 'r')
# Out:
# <__array_function__ internals>:180: RuntimeWarning: Converting input from bool to <class 'numpy.uint8'> for compatibility.
# <Axes: xlabel='GridFins', ylabel='Count'>

# %%
plt.subplot(1,2,1)
sns.histplot(dataset.Reused,color = 'r')
# Out:
# <__array_function__ internals>:180: RuntimeWarning: Converting input from bool to <class 'numpy.uint8'> for compatibility.
# <Axes: xlabel='Reused', ylabel='Count'>

# %%
plt.subplot(1,2,1)
sns.histplot(dataset.Legs,color = 'r')
# Out:
# <__array_function__ internals>:180: RuntimeWarning: Converting input from bool to <class 'numpy.uint8'> for compatibility.
# <Axes: xlabel='Legs', ylabel='Count'>

# %%
sns.histplot(dataset.Block,color = 'r')
# Out:
# <Axes: xlabel='Block', ylabel='Count'>

# %%
sns.histplot(dataset.Outcome,color = 'r')
# Out:
# <Axes: xlabel='Outcome', ylabel='Count'>

# %%
dataset_num = dataset[['GridFins','Reused','Legs']]
sns.pairplot(dataset_num, diag_kind = 'kde')
plt.show()

# %%
plt.figure (figsize = (25,10))
plt.subplot(2,2,1)
sns.boxplot(x = 'Serial', y = 'Class', data = dataset)

plt.subplot(2,2,2)
sns.boxplot(x = 'LaunchSite', y = 'Class', data = dataset)

plt.subplot(2,2,3)
sns.boxplot(x = 'Orbit', y = 'Class', data = dataset)
# Out:
# <Axes: xlabel='Orbit', ylabel='Class'>
